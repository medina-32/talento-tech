# %%
print("ingrese la hora")
hora = int(input())

def saludar(hora):

  if 0 <= hora <=12:
    print("buenos dias")

  if 13 <= hora <=19:
    print("buenas tardes")

  if 20 <= hora <=23:
    print("buenas noches")

saludar(hora)
# Out:
# ingrese la hora
# 0
# buenos dias
