# %%
import pandas as pd

value_n_list = ["Andrew" , "Phillip" , "Jhon"]
print(value_n_list)

value_w_list =[50,    78,   91.5]
value_h_list =[1.76,  1.87, 1.69]

data_dict ={"name":value_n_list,
            "weight":value_w_list,
            "height":value_h_list}

print(data_dict)

df = pd.DataFrame(data_dict)
print(df)
df
# Out:
# ['Andrew', 'Phillip', 'Jhon']
# {'name': ['Andrew', 'Phillip', 'Jhon'], 'weight': [50, 78, 91.5], 'height': [1.76, 1.87, 1.69]}
#       name  weight  height
# 0   Andrew    50.0    1.76
# 1  Phillip    78.0    1.87
# 2     Jhon    91.5    1.69
#       name  weight  height
# 0   Andrew    50.0    1.76
# 1  Phillip    78.0    1.87
# 2     Jhon    91.5    1.69

# %%
value_n_list = ["Andrew" , "Phillip" , "Jhon", "Santiago" , "Daniel" , "Karen", "Miguel", "Sebastian", "Samuel", "Ivan"]
print(value_n_list)

value_w_list =[50,    78,   91.5,  70,    66,   71,    55,    60,    80,    76]
value_h_list =[1.76,  1.87, 1.69,  1.60,  1.57, 1.65,  1.53,  1.70,  1.40,  1.50]

data_dict ={"name":value_n_list,
            "weight":value_w_list,
            "height":value_h_list}

print(data_dict)

df = pd.DataFrame(data_dict)
print(df)
df
# Out:
# ['Andrew', 'Phillip', 'Jhon', 'Santiago', 'Daniel', 'Karen', 'Miguel', 'Sebastian', 'Samuel', 'Ivan']
# {'name': ['Andrew', 'Phillip', 'Jhon', 'Santiago', 'Daniel', 'Karen', 'Miguel', 'Sebastian', 'Samuel', 'Ivan'], 'weight': [50, 78, 91.5, 70, 66, 71, 55, 60, 80, 76], 'height': [1.76, 1.87, 1.69, 1.6, 1.57, 1.65, 1.53, 1.7, 1.4, 1.5]}
#         name  weight  height
# 0     Andrew    50.0    1.76
# 1    Phillip    78.0    1.87
# 2       Jhon    91.5    1.69
# 3   Santiago    70.0    1.60
# 4     Daniel    66.0    1.57
# 5      Karen    71.0    1.65
# 6     Miguel    55.0    1.53
# 7  Sebastian    60.0    1.70
# 8     Samuel    80.0    1.40
# 9       Ivan    76.0    1.50
#         name  weight  height
# 0     Andrew    50.0    1.76
# 1    Phillip    78.0    1.87
# 2       Jhon    91.5    1.69
# 3   Santiago    70.0    1.60
# 4     Daniel    66.0    1.57
# 5      Karen    71.0    1.65
# 6     Miguel    55.0    1.53
# 7  Sebastian    60.0    1.70
# 8     Samuel    80.0    1.40
# ...

# %%
df["bmi"] = df["weight"] / (df["height"]**2)
df
# Out:
#         name  weight  height        bmi
# 0     Andrew    50.0    1.76  16.141529
# 1    Phillip    78.0    1.87  22.305471
# 2       Jhon    91.5    1.69  32.036693
# 3   Santiago    70.0    1.60  27.343750
# 4     Daniel    66.0    1.57  26.775934
# 5      Karen    71.0    1.65  26.078972
# 6     Miguel    55.0    1.53  23.495237
# 7  Sebastian    60.0    1.70  20.761246
# 8     Samuel    80.0    1.40  40.816327
# 9       Ivan    76.0    1.50  33.777778

# %%
# prompt: con el resultado de "bmi" de la tabla asignalos con "bajo de peso" "peso normal " "sobre peso"

import pandas as pd

# ... (your existing code) ...

df["bmi"] = df["weight"] / (df["height"]**2)

def bmi_category(bmi):
  if bmi < 18.5:
    return "Bajo de peso"
  elif bmi >= 18.5 and bmi < 25:
    return "Peso normal"
  elif bmi >= 25 and bmi < 30:
    return "Sobrepeso"
  else:
    return "Obesidad"

df["bmi_category"] = df["bmi"].apply(bmi_category)
df
# Out:
#         name  weight  height        bmi  bmi_category
# 0     Andrew    50.0    1.76  16.141529  Bajo de peso
# 1    Phillip    78.0    1.87  22.305471   Peso normal
# 2       Jhon    91.5    1.69  32.036693      Obesidad
# 3   Santiago    70.0    1.60  27.343750     Sobrepeso
# 4     Daniel    66.0    1.57  26.775934     Sobrepeso
# 5      Karen    71.0    1.65  26.078972     Sobrepeso
# 6     Miguel    55.0    1.53  23.495237   Peso normal
# 7  Sebastian    60.0    1.70  20.761246   Peso normal
# 8     Samuel    80.0    1.40  40.816327      Obesidad
# 9       Ivan    76.0    1.50  33.777778      Obesidad
