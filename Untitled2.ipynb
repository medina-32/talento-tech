# %% [markdown]
# lista_para_hacer_arepas_de_queso=["harina de maiz","leche o agua","queso","azucar","mantequilla"]
#
# print(lista_para_hacer_arepas_de_queso)
#
# tipos_de_pizza_mas_populares=("Napolitana","Margarita","Marinera","Carbonara","Barbacoa"," Hawaiana")
#
# print(tipos_de_pizza_mas_populares)
#
# platos_tipicos_de_colombia={"bandeja paisa","Ajiaco","sancocho","Hormigas culonas","empanadas"}
#
# lista_para_hacer_arepas_de_queso=["harina de maiz","leche o agua","queso","azucar","mantequilla"]
#
# print(lista_para_hacer_arepas_de_queso)
#
# tipos_de_pizza_mas_populares=("Napolitana","Margarita","Marinera","Carbonara","Barbacoa"," Hawaiana")
#
# print(tipos_de_pizza_mas_populares)
#
# platos_tipicos_de_colombia={"bandeja paisa","Ajiaco","sancocho","Hormigas culonas","empanadas"}
#
# print(platos_tipicos_de_colombia)
#
# diccionario={"aguacate":"fruta tropical","estadio":"resinto para espectadores, destinados a competiciones deportivas","iguana":"animal","oeste":"punto cardinal","ucrania":"pais"}
#
# print(diccionario)
